# %%
#PRASANNA MURUGESAN
#CB.EN.U4CSE20247
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#1
df = pd.read_csv('Absenteeism_at_work.csv',sep = ';',engine = 'python')

# %%
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Reason for absence', 'Month of absence', 'Day of the week',
#        'Seasons', 'Transportation expense', 'Distance from Residence to Work',
#        'Service time', 'Age', 'Work load Average/day ', 'Hit target',
#        'Disciplinary failure', 'Education', 'Son', 'Social drinker',
#        'Social smoker', 'Pet', 'Weight', 'Height', 'Body mass index',
#        'Absenteeism time in hours'],
#       dtype='object')

# %%
#2) Son and Pet are not required for our analysis
df.drop(['Son', 'Pet'], axis=1,inplace=True)

# %%
df.sample(3)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 645   3                  27                 3                6        2
# 295  22                   1                10                2        4
# 121  34                  27                 1                2        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 645                     179                               51            18
# 295                     179                               26             9
# 121                     118                               10            10
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 645   38                 222.196          99                     0          1
# 295   30                 265.017          88                     0          3
# 121   37                 308.593          95                     0          1
#
# ...

# %%
#3
df.isnull().sum()
# Out:
# ID                                 0
# Reason for absence                 0
# Month of absence                   0
# Day of the week                    0
# Seasons                            0
# Transportation expense             0
# Distance from Residence to Work    0
# Service time                       0
# Age                                0
# Work load Average/day              0
# Hit target                         0
# Disciplinary failure               0
# Education                          0
# Social drinker                     0
# Social smoker                      0
# Weight                             0
# Height                             0
# Body mass index                    0
# Absenteeism time in hours          0
# dtype: int64

# %%
#3
df.dropna(axis=0,how='any',inplace=True)
df
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 3     7                   7                 7                5        1
# 4    11                  23                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#4
df.boxplot(column=['Age','Weight'])

# %% [markdown]
# #60 is a outlier in age since it is placed farther than whisker

# %%
#5correlation

df['Age'].corr(df['Body mass index'])
# Out:
# 0.47068801697888635

# %%
#6
df.describe()
# Out:
#                ID  Reason for absence  Month of absence  Day of the week  \
# count  740.000000          740.000000        740.000000       740.000000
# mean    18.017568           19.216216          6.324324         3.914865
# std     11.021247            8.433406          3.436287         1.421675
# min      1.000000            0.000000          0.000000         2.000000
# 25%      9.000000           13.000000          3.000000         3.000000
# 50%     18.000000           23.000000          6.000000         4.000000
# 75%     28.000000           26.000000          9.000000         5.000000
# max     36.000000           28.000000         12.000000         6.000000
#
#           Seasons  Transportation expense  Distance from Residence to Work  \
# count  740.000000              740.000000                       740.000000
# mean     2.544595              221.329730                        29.631081
# std      1.111831               66.952223                        14.836788
# ...

# %%
#7
df.head(3)
# Out:
#    ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0  11                  26                 7                3        1
# 1  36                   0                 7                3        1
# 2   3                  23                 7                4        1
#
#    Transportation expense  Distance from Residence to Work  Service time  Age  \
# 0                     289                               36            13   33
# 1                     118                               13            18   50
# 2                     179                               51            18   38
#
#    Work load Average/day   Hit target  Disciplinary failure  Education  \
# 0                 239.554          97                     0          1
# 1                 239.554          97                     1          1
# 2                 239.554          97                     0          1
#
#    Social drinker  Social smoker  Weight  Height  Body mass index  \
# ...

# %%
#8
df.tail(4)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 736   1                  11                 7                3        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
# 739  35                   0                 0                6        3
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 736                     235                               11            14
# 737                     118                               14            13
# 738                     231                               35            14
# 739                     179                               45            14
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 736   37                 264.604          93                     0          3
# ...

# %%
#9
df.iloc[(df.index%1000)==247].head(1)
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 247  11                  26                 7                4        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# 247                     289                               36            13
#
#      Age  Work load Average/day   Hit target  Disciplinary failure  Education  \
# 247   33                 275.312          98                     0          1
#
#      Social drinker  Social smoker  Weight  Height  Body mass index  \
# 247               1              0      90     172               30
#
#      Absenteeism time in hours
# 247                          8

# %%
#10 total rows
df.shape[0]
# Out:
# 740

# %%
#11
df.iloc[0,:5]
# Out:
# ID                    11.0
# Reason for absence    26.0
# Month of absence       7.0
# Day of the week        3.0
# Seasons                1.0
# Name: 0, dtype: float64

# %%
#12
df[df["Reason for absence"]==9].count()[0]
# Out:
# 4

# %%
#13
m=df['Body mass index'] >30
gt=df[m]
n= df['Body mass index'] <=30
lt=df[n]
z=lt['Body mass index'] >25
mt=lt[z]
mt
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 0    11                  26                 7                3        1
# 4    11                  23                 7                5        1
# 6    10                  22                 7                6        1
# 9     1                  22                 7                2        1
# 22   10                  13                 8                2        1
# ..   ..                 ...               ...              ...      ...
# 728  34                  28                 7                2        1
# 731  34                  23                 7                4        1
# 732  10                  22                 7                4        1
# 735  11                  14                 7                3        1
# 736   1                  11                 7                3        1
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#13 >30 bmi
gt
# Out:
#      ID  Reason for absence  Month of absence  Day of the week  Seasons  \
# 1    36                   0                 7                3        1
# 2     3                  23                 7                4        1
# 5     3                  23                 7                6        1
# 13    3                  11                 7                4        1
# 14    3                  23                 7                4        1
# ..   ..                 ...               ...              ...      ...
# 714   2                   0                 6                2        3
# 716  36                  19                 6                5        3
# 725   5                  26                 7                4        1
# 737   4                   0                 0                3        1
# 738   8                   0                 0                4        2
#
#      Transportation expense  Distance from Residence to Work  Service time  \
# ...

# %%
#14
print(" Highscoolers is ",df["Age"][df["Education"]==1].mean(),"and",df["Age"][df["Education"]==1].std())
print("Graduates is ",df["Age"][df["Education"]==2].mean(),"and",df["Age"][df["Education"]==2].std())
print(" Postgraduates is ",df["Age"][df["Education"]==3].mean(),"and",df["Age"][df["Education"]==3].std())
# Out:
#  Highscoolers is  37.14238952536825 and 6.639006951133699
# Graduates is  34.0 and 5.501514942874069
#  Postgraduates is  32.29113924050633 and 3.105627228172035

# %%
#15
print("Mean : ",df["Transportation expense"].mean())
print("variance : ",pow(df["Transportation expense"].std(),2))
# Out:
# Mean :  221.32972972972973
# variance :  4482.600197491131

# %%
x=df["Age"][df["Social drinker"]==1]
plt.hist(x,bins=[0,20,40,60,80,100])
plt.legend();
plt.xlabel("age")
plt.title("Age of Social drinkers")
# Out:
# WARNING:matplotlib.legend:No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Age of Social drinkers')

# %%
df['Social drinker'].skew()
# Out:
# -0.2733267156901403

# %% [markdown]
# #The given data is negatively skewed
