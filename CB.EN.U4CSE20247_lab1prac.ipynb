# %%
import pandas as pd

# %%
data = pd.read_csv('test1.csv')

# %%
data
# Out:
#        Unnamed: 0  39          State-gov   77516    Bachelors   13  \
# 0               0  50   Self-emp-not-inc   83311    Bachelors   13
# 1               1  38            Private  215646      HS-grad    9
# 2               2  53            Private  234721         11th    7
# 3               3  28            Private  338409    Bachelors   13
# 4               4  37            Private  284582      Masters   14
# ...           ...  ..                ...     ...          ...  ...
# 32555       32555  27            Private  257302   Assoc-acdm   12
# 32556       32556  40            Private  154374      HS-grad    9
# 32557       32557  58            Private  151910      HS-grad    9
# 32558       32558  22            Private  201490      HS-grad    9
# 32559       32559  52       Self-emp-inc  287927      HS-grad    9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0            39         77516            13          2174  \
# count  32560.000000  32560.000000  3.256000e+04  32560.000000  32560.000000
# mean   16279.500000     38.581634  1.897818e+05     10.080590   1077.615172
# std     9399.406719     13.640642  1.055498e+05      2.572709   7385.402999
# min        0.000000     17.000000  1.228500e+04      1.000000      0.000000
# 25%     8139.750000     28.000000  1.178315e+05      9.000000      0.000000
# 50%    16279.500000     37.000000  1.783630e+05     10.000000      0.000000
# 75%    24419.250000     48.000000  2.370545e+05     12.000000      0.000000
# max    32559.000000     90.000000  1.484705e+06     16.000000  99999.000000
#
#                   0            40
# count  32560.000000  32560.000000
# mean      87.306511     40.437469
# std      402.966116     12.347618
# min        0.000000      1.000000
# 25%        0.000000     40.000000
# 50%        0.000000     40.000000
# 75%        0.000000     45.000000
# ...

# %%
data.head(3)
# Out:
#    Unnamed: 0  39          State-gov   77516   Bachelors   13  \
# 0           0  50   Self-emp-not-inc   83311   Bachelors   13
# 1           1  38            Private  215646     HS-grad    9
# 2           2  53            Private  234721        11th    7
#
#          Never-married        Adm-clerical   Not-in-family   White   Male  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White   Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White   Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black   Male
#
#     2174   0   40   United-States   <=50K
# 0      0   0   13   United-States   <=50K
# 1      0   0   40   United-States   <=50K
# 2      0   0   40   United-States   <=50K

# %%
data.tail(4)
# Out:
#        Unnamed: 0  39      State-gov   77516  Bachelors   13  \
# 32556       32556  40        Private  154374    HS-grad    9
# 32557       32557  58        Private  151910    HS-grad    9
# 32558       32558  22        Private  201490    HS-grad    9
# 32559       32559  52   Self-emp-inc  287927    HS-grad    9
#
#              Never-married        Adm-clerical  Not-in-family   White  \
# 32556   Married-civ-spouse   Machine-op-inspct        Husband   White
# 32557              Widowed        Adm-clerical      Unmarried   White
# 32558        Never-married        Adm-clerical      Own-child   White
# 32559   Married-civ-spouse     Exec-managerial           Wife   White
#
#           Male   2174   0   40   United-States   <=50K
# 32556     Male      0   0   40   United-States    >50K
# 32557   Female      0   0   40   United-States   <=50K
# 32558     Male      0   0   20   United-States   <=50K
# 32559   Female  15024   0   40   United-States    >50K

# %%
data.iloc[255]
# Out:
# Unnamed: 0                   255
# 39                            20
#  State-gov               Private
#  77516                    117789
#  Bachelors               HS-grad
#  13                            9
#  Never-married     Never-married
#  Adm-clerical      Other-service
#  Not-in-family         Own-child
#  White                     White
#  Male                     Female
#  2174                          0
#  0                             0
#  40                           40
#  United-States     United-States
#  <=50K                     <=50K
# Name: 255, dtype: object

# %%
data.rename(columns={'<=50K':'Income'},inplace=True)

# %%
data
# Out:
#        Unnamed: 0  39          State-gov   77516    Bachelors   13  \
# 0               0  50   Self-emp-not-inc   83311    Bachelors   13
# 1               1  38            Private  215646      HS-grad    9
# 2               2  53            Private  234721         11th    7
# 3               3  28            Private  338409    Bachelors   13
# 4               4  37            Private  284582      Masters   14
# ...           ...  ..                ...     ...          ...  ...
# 32555       32555  27            Private  257302   Assoc-acdm   12
# 32556       32556  40            Private  154374      HS-grad    9
# 32557       32557  58            Private  151910      HS-grad    9
# 32558       32558  22            Private  201490      HS-grad    9
# 32559       32559  52       Self-emp-inc  287927      HS-grad    9
#
#              Never-married        Adm-clerical   Not-in-family   White  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
# data.groupby('United-States').value_counts()
data.columns
# Out:
# Index(['Unnamed: 0', '39', ' State-gov', ' 77516', ' Bachelors', ' 13',
#        ' Never-married', ' Adm-clerical', ' Not-in-family', ' White', ' Male',
#        ' 2174', ' 0', ' 40', ' United-States', ' <=50K'],
#       dtype='object')

# %%
data[' United-States'].value_counts()
# Out:
#  United-States                 29169
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
data[data[' Male'] == ' Male'][' Male'].count()
# Out:
# 21789

# %%
data[' Male'][data[' <=50K'] == ' <=50K'].value_counts()
# Out:
#  Male      15127
#  Female     9592
# Name:  Male, dtype: int64

# %%
data[(data[' Male'] == ' Male') & (data[' <=50K'] == ' >50K')][' Male'].count()
# Out:
# 6662

# %%
newdata = data[['39',' <=50K']]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data['39'],data[' <=50K'])
plt.show()

# %%
plt.hist(data['39'],bins=10)
plt.show()

# %%
data[data[' Male'] == ' Male']['39'].head()
# Out:
# 0    50
# 1    38
# 2    53
# 6    52
# 8    42
# Name: 39, dtype: int64

# %%
newdata = data[data[' Male'] == ' Male']['39']
newdata
# plt.hist(data[data[' Male'] == ' Male']['39'].head(),bins=10)
# plt.show
# Out:
# 0        50
# 1        38
# 2        53
# 6        52
# 8        42
#          ..
# 32552    32
# 32553    53
# 32554    22
# 32556    40
# 32558    22
# Name: 39, Length: 21789, dtype: int64

# %%
plt.hist(newdata,bins=10)
plt.show()

# %%
new = data['39']

# %%
newpmf = new.value_counts().sort_index()/len(new)

# %%
newpmf.plot.bar()
# Out:
# <AxesSubplot:>
